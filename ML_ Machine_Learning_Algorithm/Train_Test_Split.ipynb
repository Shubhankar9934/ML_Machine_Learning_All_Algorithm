# %% [markdown]
# # Machine Learning (Train , Test , Split)

# %% [raw]
# train_test_split() is a scikit-Learn class help to split data
# in 4 dataset (like : X_train , X_test , y_train , y_test)

# %% [raw]
# X_train means Independent Feature
# Y_train means Dependent Feature

# %%
import pandas as pd 
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2 = df[['survived','pclass','age','parch']] # Creating new dataframe using some column
df3 = df2.fillna(df2.mean())# Cleaning Of dataset using mean.
df3
# Out:
#      survived  pclass        age  parch
# 0           0       3  22.000000      0
# 1           1       1  38.000000      0
# 2           1       3  26.000000      0
# 3           1       1  35.000000      0
# 4           0       3  35.000000      0
# ..        ...     ...        ...    ...
# 886         0       2  27.000000      0
# 887         1       1  19.000000      0
# 888         0       3  29.699118      2
# 889         1       1  26.000000      0
# 890         0       3  32.000000      0
#
# [891 rows x 4 columns]

# %%
X = df3.drop("survived",axis = 1)
y = df3["survived"]

print("Shape of X = ", X.shape)
print("Shape of y = ", y.shape)
# Out:
# Shape of X =  (891, 3)
# Shape of y =  (891,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y , test_size = 0.2, random_state = 51 )
print("Shape of X_train = ", X_train.shape)
print("Shape of y_train = ", y_train.shape)
print("Shape of X_test = ", X_test.shape)
print("Shape of y_test = ", y_test.shape)
# Out:
# Shape of X_train =  (712, 3)
# Shape of y_train =  (712,)
# Shape of X_test =  (179, 3)
# Shape of y_test =  (179,)

# %%
X_train
# Out:
#      pclass        age  parch
# 770       3  24.000000      0
# 152       3  55.500000      0
# 731       3  11.000000      0
# 775       3  18.000000      0
# 324       3  29.699118      2
# ..      ...        ...    ...
# 528       3  39.000000      0
# 709       3  29.699118      1
# 736       3  48.000000      3
# 485       3  29.699118      1
# 57        3  28.500000      0
#
# [712 rows x 3 columns]
